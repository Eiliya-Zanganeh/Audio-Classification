# %%
from train import train, test
# Out:
# Device: cuda | Device Name: NVIDIA GeForce RTX 3060 Laptop GPU
# Mapping: {'Abdollah': 0, 'Alireza': 1, 'Azra': 2, 'Benyamin': 3, 'Davood': 4, 'Javad': 5, 'Khadijeh': 6, 'Kiana': 7, 'Maryam': 8, 'Matin': 9, 'Melika': 10, 'MohammadN': 11, 'MohammadP': 12, 'Mohammadali': 13, 'Mona': 14, 'Morteza': 15, 'Nahid': 16, 'Nima': 17, 'Omid': 18, 'Parisa': 19, 'Parsa': 20, 'Sajedeh': 21, 'Sajjad': 22, 'Shima': 23, 'Tara': 24, 'Zahra': 25, 'Zeynab': 26}
# len dataset: 2203 from 27 classes
# Train: 1762
# Validation: 111
# Test: 330

# %%
train()
# Out:
# Epoch [1/50]
# Train Loss:  2.9816 | Train Accuracy:  0.1199
# Validation Loss: 2.6208 | Validation Accuracy: 0.2339
# Epoch [2/50]
# Train Loss:  2.3878 | Train Accuracy:  0.2466
# Validation Loss: 2.4301 | Validation Accuracy: 0.2690
# Epoch [3/50]
# Train Loss:  1.9600 | Train Accuracy:  0.3620
# Validation Loss: 1.8060 | Validation Accuracy: 0.4411
# Epoch [4/50]
# Train Loss:  1.7733 | Train Accuracy:  0.4144
# Validation Loss: 1.2798 | Validation Accuracy: 0.6214
# Epoch [5/50]
# Train Loss:  1.5795 | Train Accuracy:  0.4713
# Validation Loss: 1.2107 | Validation Accuracy: 0.7220
# Epoch [6/50]
# Train Loss:  1.4477 | Train Accuracy:  0.5293
# Validation Loss: 1.8080 | Validation Accuracy: 0.4696
# Epoch [7/50]
# Train Loss:  1.2808 | Train Accuracy:  0.5901
# Validation Loss: 1.2405 | Validation Accuracy: 0.6589
# Epoch [8/50]
# Train Loss:  1.3351 | Train Accuracy:  0.5777
# Validation Loss: 1.1663 | Validation Accuracy: 0.6220
# Epoch [9/50]
# ...

# %%
test()
# Out:
# Test Loss: 0.5232, Test Accuracy: 84.46%
